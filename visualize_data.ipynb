# %% [markdown]
# # Visualize Data

# %% [markdown]
# This is a simple example how to visualize data with seaborn.
# http://stanford.edu/~mwaskom/software/seaborn/

# %%
# %matplotlib inline
import seaborn as sns
import pandas as pd

# %% [markdown]
# The following example displays the first tags and count from 'top_stackoverflow_tags.csv' file.

# %%
df = pd.read_csv('data/top_stackoverflow_tags.csv');
df = df.head()

print df
# Out:
#    Id     TagName   Count  ExcerptPostId  WikiPostId
# 0   1        .net  216781        3624959     3607476
# 1   2        html  453768        3673183     3673182
# 2   3  javascript  937830        3624960     3607052
# 3   4         css  332802        3644670     3644669
# 4   5         php  803687        3624936     3607050

# %% [markdown]
# We can now plot the TagName and Count fields from the pandas DataFrame.

# %%
sns.barplot(x = df['TagName'], y = df['Count'], color = "red")

# %% [markdown]
# Or we could plot stations from the swiss public transportaion. http://www.fahrplanfelder.ch/

# %%
df = pd.read_csv('data/stations_CH.csv', sep=';',header=None);
df.columns=['x', 'y', 'station']

print df.head()
# Out:
#          x        y         station
# 0  608.420  229.470  St. Katharinen
# 1  774.787  199.364         Fideris
# 2  510.093  141.630           Gland
# 3  596.274  226.763   Grenchen Nord
# 4  605.092  198.138        Gümligen

# %% [markdown]
# We have now the x and y coordinates, which we will print in a scaterplot.

# %%
sns.jointplot(x="x", y="y", data=df, stat_func=None, xlim=(450, 850), ylim=(10,450), size=10)

# %% [markdown]
# We can plot the same data as kernel density estimation

# %%
sns.jointplot(x="x", y="y", data=df, kind="kde", xlim=(450, 850), ylim=(10,450))
