# %% [markdown]
# # Visualize Data

# %% [markdown]
# This is a simple example how to visualize data with seaborn.
# http://stanford.edu/~mwaskom/software/seaborn/

# %%
# %matplotlib inline
import seaborn as sns
import pandas as pd

# %% [markdown]
# The following example displays the first tags and count as bar chart.

# %%
df = pd.read_csv('data/top_stackoverflow_tags.csv');
df = df.head()

sns.barplot(x = df['TagName'], y = df['Count'], color = "red")
